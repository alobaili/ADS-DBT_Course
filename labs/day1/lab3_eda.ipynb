# %% [markdown]
# <!-- Qalhata Technologies | Applied Data Science & ML with Python and dbt -->
# # Lab 3 - Explore and find one insight
#
# **Day 1 lab**
#
# > Convention for this course: run cells top to bottom. Before you trust a result, use **Kernel > Restart Kernel and Run All Cells**. If it survives that, it is real.

# %% [markdown]
# ## Lab 3 | Explore, and find one insight  ·  ~60 minutes
#
# Use the **four EDA questions** from the slides on your cleaned data, then state **one finding in plain English** at the end. That sentence is the deliverable.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
# Load your cleaned data from data/processed/service_requests_clean.csv
# (parse submitted_at and resolved_at as dates). Tip: reuse the find_data_dir
# helper pattern from Lab 1 so the path works from any folder.
# TODO: your code here

# %% [markdown]
# ### Q1 - What is in here?
# `describe()` for numbers, `info()` for structure.

# %%
# describe() the dataframe
# TODO: your code here

# %% [markdown]
# ### Q2 - How common is each category?
# Check `priority` and `status`. After cleaning, each label should now be single and sensible.

# %%
# value_counts for priority and status
# TODO: your code here

# %% [markdown]
# ### Q3 - Does the target differ by group?
# Mean resolution time by channel. Join the channel names to make it readable. This is where the first real insight usually appears.

# %%
# Merge channels, group by channel_name, mean of resolution_hours, sort
# TODO: your code here

# %%
# Make a horizontal bar chart of by_channel (a taste of Day 2)
# TODO: your code here

# %% [markdown]
# ### Q4 - What moves with what?
# A quick correlation on the numeric columns. Early hints at features for the Day 3 model.

# %%
# Correlation across the numeric columns
# TODO: your code here

# %% [markdown]
# ### Your one finding
# In one or two sentences of plain English, state something true and useful you found, as if telling a service manager who has never seen the data.
#
# Example *shape* (not the answer): *"Requests in group A take roughly N hours longer to resolve than requests in group B, which suggests it is worth looking at ..."*
#
# Say what the data shows, and what you would investigate next. Remember a difference between groups is not proof that one causes the other.
#
# _Write your finding here:_
#
# > ...

# %% [markdown]
# **Wrap-up:** you took a messy extract to a cleaned, explored dataset and a stated insight - a complete, if small, analytics workflow in a day. Tomorrow we make this visual and persuasive with Matplotlib and Seaborn.
